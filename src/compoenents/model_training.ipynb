# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\iNeuronai\\Project\\Diamond_price_prediction\\notebook\\data\\gemstone.csv')

# %%
df
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1          1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2          2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3          3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4          4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 9996    9996   2.20    Premium     J     SI2   62.6   59.0  8.31  8.25  5.18
# 9997    9997   2.05    Premium     D     SI2   58.8   59.0  8.32  8.26  4.93
# 9998    9998   0.71      Ideal     E    VVS2   61.0   56.0  5.74  5.77  3.51
# 9999    9999   1.02      Ideal     F     VS2   61.8   57.0  6.42  6.46  3.99
# 10000  10000   0.44      Ideal     E     VS1   62.8   56.0  4.85  4.81  3.03
#
#        price
# 0      13619
# 1      13387
# ...

# %%
df = df.drop(labels=['id'],axis=1)

# %%
#Independent and dependent feature
X= df.drop(labels=['price'],axis=1)
Y = df[['price']]

# %%
Y
# Out:
#        price
# 0      13619
# 1      13387
# 2       2772
# 3        666
# 4      14453
# ...      ...
# 9996   12787
# 9997   10036
# 9998    3271
# 9999    6666
# 10000   1155
#
# [10001 rows x 1 columns]

# %%
#Define which columns shoud be ordinal-encoding and which should be scaled
cateogarical_col = X.select_dtypes(include='object').columns
numerical_cols = X.select_dtypes(exclude='object').columns

# %%
X
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 0       1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1       2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2       0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3       0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4       1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 9996    2.20    Premium     J     SI2   62.6   59.0  8.31  8.25  5.18
# 9997    2.05    Premium     D     SI2   58.8   59.0  8.32  8.26  4.93
# 9998    0.71      Ideal     E    VVS2   61.0   56.0  5.74  5.77  3.51
# 9999    1.02      Ideal     F     VS2   61.8   57.0  6.42  6.46  3.99
# 10000   0.44      Ideal     E     VS1   62.8   56.0  4.85  4.81  3.03
#
# [10001 rows x 9 columns]

# %%
# Define the custom ranking for each ordinal variable
cut_categories = ['Fair', 'Good', 'Very Good','Premium','Ideal']
color_categories = ['D', 'E', 'F', 'G', 'H', 'I', 'J']
clarity_categories = ['I1','SI2','SI1','VS2','VS1','VVS2','VVS1','IF']

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values
from sklearn.preprocessing import StandardScaler # HAndling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder # Ordinal Encoding
## pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
## Numerical Pipeline
num_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())

    ]

)

# Categorigal Pipeline
cat_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('ordinalencoder',OrdinalEncoder(categories=[cut_categories,color_categories,clarity_categories])),
    ('scaler',StandardScaler())
    ]

)

preprocessor=ColumnTransformer([
('num_pipeline',num_pipeline,numerical_cols),
('cat_pipeline',cat_pipeline,cateogarical_col)
])

# %%
## Train test split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.30,random_state=30)

# %%
X_train
# Out:
#       carat      cut color clarity  depth  table     x     y     z
# 6374   1.01     Good     G     VS2   63.6   56.0  6.36  6.32  4.03
# 9023   0.52    Ideal     D     VS2   62.0   56.0  5.15  5.20  3.20
# 5279   0.73  Premium     F    VVS2   60.9   59.0  5.78  5.80  3.53
# 6076   0.54    Ideal     F     SI1   61.0   57.0  5.24  5.27  3.21
# 3869   0.70    Ideal     F     SI1   62.9   57.0  5.69  5.66  3.57
# ...     ...      ...   ...     ...    ...    ...   ...   ...   ...
# 4859   1.01     Good     G     SI1   62.9   61.0  6.29  6.33  3.96
# 919    0.52    Ideal     D     VS1   61.1   56.0  5.20  5.22  3.19
# 500    0.38    Ideal     H     SI1   61.5   57.0  4.66  4.70  2.88
# 4517   1.02     Good     D     SI2   59.8   60.0  6.52  6.47  3.88
# 5925   0.64    Ideal     G     VS1   61.9   55.0  5.57  5.54  3.42
#
# [7000 rows x 9 columns]

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\iNeuronai\Project\Diamond_price_prediction\src\compoenents\model_training.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/iNeuronai/Project/Diamond_price_prediction/src/compoenents/model_training.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
#
# File c:\Users\prati\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:481, in ColumnTransformer.get_feature_names_out(self, input_features)
#     479 transformer_with_feature_names_out = []
#     480 for name, trans, column, _ in self._iter(fitted=True):
# --> 481     feature_names_out = self._get_feature_name_out_for_transformer(
#     482         name, trans, column, input_features
#     483     )
#     484     if feature_names_out is None:
# ...

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\iNeuronai\Project\Diamond_price_prediction\src\compoenents\model_training.ipynb Cell 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/iNeuronai/Project/Diamond_price_prediction/src/compoenents/model_training.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
#       <a href='vscode-notebook-cell:/d%3A/iNeuronai/Project/Diamond_price_prediction/src/compoenents/model_training.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())
#
# File c:\Users\prati\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:481, in ColumnTransformer.get_feature_names_out(self, input_features)
#     479 transformer_with_feature_names_out = []
# ...
